# %%
from bs4 import BeautifulSoup
import urllib
import urllib.request

def make_soup(url):
    thepage = urllib.request.urlopen(url)
    soupdata = BeautifulSoup(thepage, 'html.parser')
    return soupdata


##########Here, you will get Image according to SKU ###########################

from selenium import webdriver
import time
import urllib
import urllib.request
import os
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Firefox(executable_path=".\geckodriver.exe")
driver.maximize_window()

# %%
driver.get("https://www.olx.in/mumbai_g4058997/cars_c84")
driver.set_page_load_timeout(200)

# %%
href=[]

# %%
count=1
while(True):
    if (count==3000):
        break
    scroll(driver,2)
    try:
        driver.find_element_by_class_name('JbJAl').click()
    except:
        pass
    time.sleep(1)
    print(count)
    count =  count + 1
    elems = driver.find_elements_by_xpath("//a[@href]")
    for elem in elems:
        lop = elem.get_attribute("href")
        if '/item/' in lop:
            href.append(lop)
    href = set(href)
    href = list(href)
    print(len(href))
# Out:
# 1
# 40
# 2
# 120
# 3
# 160
# 4
# 200
# 5
# 240
# 6
# 280
# 7
# 319
# 8
# 359
# 9
# 398
# 10
# 438
# 11
# 478
# 12
# 518
# 13
# 531
# 14
# 531
# 15
# 531
# 16
# 531
# 17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-c92d5578be49> in <module>
#      13     elems = driver.find_elements_by_xpath("//a[@href]")
#      14     for elem in elems:
# ---> 15         lop = elem.get_attribute("href")
#      16         if '/item/' in lop:
#      17             href.append(lop)
#
# c:\users\administrator\miniconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     137         attributeValue = ''
#     138         if self._w3c:
# --> 139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
#     141                 self, name)
#
# ...

# %%
save = href

# %%
print(k)
# Out:
# 173

# %%
count=1865
p=10103
for k in range(0, len(href)):
    try:
        url = href[k]

        soup = make_soup(url)

        mydivs = soup.findAll('div', attrs={'class': "_3cc9E"})
        directory  = str(count)        
        download_folder_path = ".\olx_cars/" 
        path = os.path.join(download_folder_path, directory)       
        os.mkdir(path)
        count = count + 1
        brea=1
        for div in mydivs:
            if (brea==7):
                break
            word = div.prettify()
            first = word.find('https')
            second = word.find('s=82x0')
            second = second + 6
            word = word[first:second]
            print(word)
            word = word.replace('s=82x0', 's=1080x1080')
            print(word)
            brea = brea + 1
            filename = str(p)
            try:
                imagefile = open(path + '/' + filename + ".jpg", 'wb')
                imagefile.write(urllib.request.urlopen(word).read())
                imagefile.close()
                p = p + 1
            except:
                continue
    except:
        continue
# Out:
# https://apollo-singapore.akamaized.net:443/v1/files/c8qfcl4oj4se2-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/c8qfcl4oj4se2-IN/image;s=1080x1080
# https://apollo-singapore.akamaized.net:443/v1/files/cfshq1091nj01-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/cfshq1091nj01-IN/image;s=1080x1080
# https://apollo-singapore.akamaized.net:443/v1/files/ys5uehxkdjp01-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/ys5uehxkdjp01-IN/image;s=1080x1080
# https://apollo-singapore.akamaized.net:443/v1/files/um8ww3o71jxo3-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/um8ww3o71jxo3-IN/image;s=1080x1080
# https://apollo-singapore.akamaized.net:443/v1/files/mb1wd0sw2byb2-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/mb1wd0sw2byb2-IN/image;s=1080x1080
# https://apollo-singapore.akamaized.net:443/v1/files/15obhsvi9klj3-IN/image;s=82x0
# ...

# %%
mydivs = soup.findAll('div', attrs={'class': "_3cc9E"})

for div in mydivs:
    word = div.prettify()
    first = word.find('https')
    second = word.find('s=82x0')
    second = second + 6
    word = word[first:second]
    print(word)
# Out:
# https://apollo-singapore.akamaized.net:443/v1/files/vrxw8ojajcbn1-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/kwr4rzc53l923-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/s5hvfi4cw1dc2-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/msnnxr5c1pni2-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/6fjv3dzkqu0f3-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/p5wigcb8duqy-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/dtymekttg1921-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/p06vz0nrxvkf3-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/orr1nq98kw2q3-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/q33tivc69ipm-IN/image;s=82x0
# https://apollo-singapore.akamaized.net:443/v1/files/i75kagh7mb353-IN/image;s=82x0
# ...

# %%
print(len(href))
# Out:
# 861
